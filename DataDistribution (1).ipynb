# %% [markdown]
# # **Normal Distribution**
#
# N.D purely mean value(like assumption)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.random.normal(loc=60,scale=3,size=100)
x
# Out:
# array([56.68985561, 64.47813992, 56.37822089, 59.3490047 , 61.63841064,
#        61.33893164, 60.50260092, 58.92011888, 61.30074962, 61.14911294,
#        59.04607213, 61.57295557, 58.38054542, 57.66599519, 59.4497903 ,
#        60.39471715, 62.45096725, 60.07076384, 64.96417281, 59.45582691,
#        61.67354829, 59.04093677, 61.33506442, 57.39875577, 62.19207974,
#        60.85686833, 65.35153695, 59.75476276, 57.0589452 , 63.94904355,
#        59.29119639, 63.41821494, 61.62316023, 61.68519757, 58.15453214,
#        65.18602082, 57.66684881, 63.09681462, 55.14087828, 58.63748977,
#        57.26427539, 59.89797741, 62.17916037, 59.38629345, 60.81503985,
#        58.68379426, 63.31394479, 60.61088054, 56.41600889, 66.0843306 ,
#        61.4114384 , 59.57970541, 62.3499934 , 61.25553412, 55.99223221,
#        63.66472007, 61.42621487, 55.51262144, 60.4183393 , 62.00089039,
#        61.58458008, 58.41173892, 60.04460509, 56.59721632, 62.58894243,
# ...

# %%
x.mean() # loc nothing but it is a mean
# Out:
# 60.34158980012654

# %%
plt.plot(x)
plt.show()

# %%
x=np.random.normal(loc=60,scale=3,size=1000)
x
# Out:
# array([59.98615816, 65.02111285, 60.24497102, 61.6294575 , 62.65563915,
#        62.25026038, 61.5373375 , 57.1092016 , 62.56772083, 59.35485783,
#        62.73210495, 65.42117979, 59.07711572, 61.77983564, 62.8570925 ,
#        59.57047439, 58.13675983, 60.10950127, 60.12555644, 54.76502502,
#        61.84081129, 60.19681426, 62.69212744, 61.99756964, 58.58432131,
#        57.32979096, 59.93447399, 56.64007125, 59.44354193, 60.55455228,
#        60.12537108, 59.20892426, 61.59351647, 60.98330205, 58.87192635,
#        59.5250418 , 57.59095275, 63.22493569, 57.5353567 , 59.43246337,
#        60.95203441, 55.48977138, 56.92121371, 58.32090439, 56.75390394,
#        60.61116047, 55.71026997, 59.39438195, 57.2553199 , 62.26687464,
#        57.19215688, 55.03063487, 57.90119973, 59.78509718, 57.34482187,
#        61.69862627, 62.87032289, 56.65789627, 54.99954383, 64.01394318,
#        60.81267789, 58.49111129, 61.90295094, 59.25450165, 61.21195056,
# ...

# %%
x.mean()
# Out:
# 59.9504658998746

# %%
plt.plot(x)
plt.show()

# %% [markdown]
# # mean,from the mean how it normaly deviated from the mean is standard deviation
# **SCALE is SD**
# **LOC is mean**
#
# # How it maximum varied from the mean is variance

# %%
#sd2 is variance

# %%
x.min(),x.max()
# Out:
# (48.28526222282339, 69.47476859662177)

# %%
a=(x.max()-x.min())/10
a
# Out:
# 2.118950637379838

# %%
x.min(),x.min()+a,x.min()+2*a,x.min()+3*a,x.min()+4*a,x.min()+5*a,x.min()+6*a,x.min()+7*a,x.min()+8*a,x.min()+9*a,x.min()
# Out:
# (48.28526222282339,
#  50.40421286020323,
#  52.52316349758307,
#  54.64211413496291,
#  56.76106477234274,
#  58.88001540972258,
#  60.99896604710242,
#  63.11791668448226,
#  65.23686732186209,
#  67.35581795924193,
#  48.28526222282339)

# %%
plt.hist(x,bins=10)
plt.show()

# %%
plt.hist(x,bins=10,color='red')
# Out:
# (array([  3.,   4.,  31., 109., 215., 260., 243., 104.,  26.,   5.]),
#  array([48.28526222, 50.40421286, 52.5231635 , 54.64211413, 56.76106477,
#         58.88001541, 60.99896605, 63.11791668, 65.23686732, 67.35581796,
#         69.4747686 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(x)   #Density plot for normal distribution
plt.show()

# %%
sns.histplot(x,kde=True)
plt.show()

# %% [markdown]
# uses of the plot, we are taking a one day data,checking wether, it is float or int, if it is float .
#
#
# There is a two type of distribution:
#
#
# 1.**Continuous distribution**(float dtype)
#
#
# 2.**discrete distribution**(int float dtype)

# %% [markdown]
# Stimulating the data by normal distribution

# %% [markdown]
# we need only SD and Mean to generate the data

# %%
# generating the data

# %%
x=np.random.random(1500)
x
# Out:
# array([0.01100952, 0.3210184 , 0.31887243, ..., 0.37222675, 0.59645561,
#        0.18185871])

# %%
x.std()
# Out:
# 0.29486925199302416

# %%
x.mean()
# Out:
# 0.5053810315752285

# %%
x=np.random.normal(loc=0.505,scale=0.294,size=1500)
x
# Out:
# array([0.15541574, 0.42928659, 0.69989549, ..., 0.51845226, 0.95146612,
#        1.03522226])

# %%
plt.hist(x,bins=10)
# Out:
# (array([  5.,  32.,  98., 235., 339., 391., 249., 108.,  38.,   5.]),
#  array([-0.49649646, -0.29849931, -0.10050215,  0.097495  ,  0.29549216,
#          0.49348931,  0.69148647,  0.88948362,  1.08748078,  1.28547793,
#          1.48347509]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # *** BINOMIAL DISTRIBUTION***

# %% [markdown]
# # **tHIS IS A DISCRETE DISTRIBUTION(INT)**
#
# ---

# %%
#now the chennai highest temperature is 110 ,so 110 posibility is there to come 110

#now today is 99,then,99/110=0.818

#probability=0.818

#q=1-p

# %%
x=np.random.binomial(n=110,p=0.818,size=1000)
x
# Out:
# array([ 90,  96,  82,  88,  90,  95,  89,  90,  88,  89,  90,  92,  91,
#         91,  87,  92,  89,  84,  89,  93,  82,  94,  88,  91,  88,  85,
#         92,  89,  92,  92,  87,  92,  88,  85,  88,  81,  88,  90, 100,
#         91,  82,  85,  86,  91,  97,  92,  88,  94,  93,  84,  91,  89,
#         89,  91,  94,  88,  91,  85,  93,  83,  89,  91,  92,  92,  87,
#         93,  93,  86,  92,  92,  88,  94,  87,  91,  94,  87,  87,  94,
#         92,  92,  91,  86,  87,  89,  96,  95,  92,  90,  89,  83,  98,
#         90,  90,  94,  87,  95,  89,  91,  86,  89,  90,  92,  90,  89,
#         91,  86,  90,  87,  89,  92,  89,  81,  81,  89,  94,  83,  88,
#         88,  96,  91,  92,  86,  86,  88,  84,  85,  92,  90,  88,  92,
#         91,  99,  96,  87,  84,  80,  93,  96,  95,  92,  87,  93,  89,
#         90,  88,  89,  94,  86,  90,  81,  97,  86,  89,  92,  95,  92,
#         87,  81,  94,  83,  83,  88,  93,  90,  89,  86,  94,  95,  91,
# ...

# %%
x.mean()
# Out:
# 89.907

# %%
plt.hist(x,bins=20)
# Out:
# (array([  1.,   1.,   3.,   5.,  19.,   9.,  61.,  40., 130.,  77., 101.,
#         188., 105., 136.,  43.,  55.,  13.,  12.,   0.,   1.]),
#  array([ 74.  ,  75.45,  76.9 ,  78.35,  79.8 ,  81.25,  82.7 ,  84.15,
#          85.6 ,  87.05,  88.5 ,  89.95,  91.4 ,  92.85,  94.3 ,  95.75,
#          97.2 ,  98.65, 100.1 , 101.55, 103.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
dir(np.random)
# Out:
# ['BitGenerator',
#  'Generator',
#  'MT19937',
#  'PCG64',
#  'PCG64DXSM',
#  'Philox',
#  'RandomState',
#  'SFC64',
#  'SeedSequence',
#  '__RandomState_ctor',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_bounded_integers',
#  '_common',
#  '_generator',
#  '_mt19937',
#  '_pcg64',
#  '_philox',
#  '_pickle',
#  '_sfc64',
#  'beta',
#  'binomial',
#  'bit_generator',
#  'bytes',
#  'chisquare',
#  'choice',
#  'default_rng',
#  'dirichlet',
#  'exponential',
#  'f',
#  'gamma',
#  'geometric',
#  'get_bit_generator',
#  'get_state',
#  'gumbel',
#  'hypergeometric',
#  'laplace',
#  'logistic',
#  'lognormal',
#  'logseries',
#  'mtrand',
#  'multinomial',
#  'multivariate_normal',
#  'negative_binomial',
#  'noncentral_chisquare',
#  'noncentral_f',
#  'normal',
#  'pareto',
#  'permutation',
#  'poisson',
#  'power',
#  'rand',
#  'randint',
#  'randn',
# ...

# %% [markdown]
# # **Null Hypothesis**  Assumption =evidence
#
# # ***Alternative Hypothesis***   Assumption|= evidence
#
# N.H is accepting but suddenly N.H is rejected then it is **Type I Error**
#
# A.H is Rejecting but suddenly A.H is Accepted then it is **Type II Error**

# %% [markdown]
# **Two Tailed Test =Aceppting the two side of critical region**![image.png](data:image/png;base64,...)
#
#
# ***One Tailed Test==Aceppting the right or left critical region***
#
# ![image.png](data:image/png;base64,...)
